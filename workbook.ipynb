# %%
import pandas as pd

# %%
#data_df = pd.read_csv("data/data.csv")
data_2014 = pd.read_csv("data/data_2014.csv")
indicator_df = pd.read_csv("data/indicators.csv")
region_df = pd.read_csv("data/regions.csv")
crime_df = pd.read_csv("data/crime.csv")
# Out:
# C:\Users\jaiti\AppData\Local\Temp\ipykernel_18140\704784300.py:5: DtypeWarning: Columns (16) have mixed types. Specify dtype option on import or set low_memory=False.
#   crime_df = pd.read_csv("data/crime.csv")

# %%
# data_df_sample = data_df.sample(n=500000).reset_index()
# data_df_sample.to_csv("data_sample.csv", index=False)

# %%
# data_df['date'] = pd.to_datetime(data_df['date'])
# data_2014 = data_df[data_df["date"].dt.year == 2014]
# data_2014.to_csv("data/data_2014.csv", index=False)

# %%
# data_2014
# region_df

# %%
merged_df = pd.merge(data_2014, region_df, on="region_id", how="left")

# %%
merged_df.groupby("region_id").agg("count")
# Out:
#            indicator_id  date  value  region_type  region
# region_id
# 3                   120   120    120          120     120
# 4                   120   120    120          120     120
# 6                   120   120    120          120     120
# 8                   120   120    120          120     120
# 9                   120   120    120          120     120
# ...                 ...   ...    ...          ...     ...
# 827645               12    12     12           12      12
# 845158              384   384    384          384     384
# 845160              384   384    384          384     384
# 845164               72    72     72           72      72
# 845167               72    72     72           72      72
#
# [81248 rows x 5 columns]

# %%
check_merge = region_df[region_df["region_id"].isin(data_2014["region_id"])]

# %%
check_merge["region_type"].unique()
# Out:
# array(['zip', 'metro', 'state', 'neigh', 'city', 'county'], dtype=object)

# %%
check_merge
# Out:
#        region_id region_type  \
# 0          96208         zip
# 1         394415       metro
# 2         394653       metro
# 3         394312       metro
# 4         394357       metro
# ...          ...         ...
# 89299      92436         zip
# 89300      59107         zip
# 89301      94027         zip
# 89302      58463         zip
# 89303      75653         zip
#
#                                                   region
# 0      90706;CA;Los Angeles-Long Beach-Anaheim, CA;Be...
# 1                                         Bridgeport, CT
# 2                                         Greenville, SC
# 3                                        Albuquerque, NM
# 4                                        Bakersfield, CA
# ...                                                  ...
# 89299  78402;TX;Corpus Christi, TX;Corpus Christi;Nue...
# 89300    3293;NH;Lebanon, NH-VT;Woodstock;Grafton County
# 89301        83025;WY;Jackson, WY-ID;Wilson;Teton County
# 89302  1718;MA;Boston-Cambridge-Newton, MA-NH;Acton;M...
# 89303                       40363;KY;nan;nan;Owen County
#
# [81248 rows x 3 columns]

# %%
check_merge_zip = check_merge[check_merge["region_type"] == "zip"].copy()
check_merge_metro = check_merge[check_merge["region_type"] == "metro"].copy()
check_merge_state = check_merge[check_merge["region_type"] == "state"].copy()
check_merge_neigh = check_merge[check_merge["region_type"] == "neigh"].copy()
check_merge_city = check_merge[check_merge["region_type"] == "city"].copy()
check_merge_county = check_merge[check_merge["region_type"] == "county"].copy()

# %% [markdown]
# ## Splice regions to only get the city and state from them

# %%
check_merge_zip.loc[:, "city"] = check_merge_zip["region"].str.split(";").str[3]
check_merge_zip.loc[:, "state"] = check_merge_zip["region"].str.split(";").str[1]

# %%
check_merge_zip
# Out:
#        region_id region_type  \
# 0          96208         zip
# 72         95315         zip
# 73         91325         zip
# 74         91732         zip
# 75         61616         zip
# ...          ...         ...
# 89299      92436         zip
# 89300      59107         zip
# 89301      94027         zip
# 89302      58463         zip
# 89303      75653         zip
#
#                                                   region            city state
# 0      90706;CA;Los Angeles-Long Beach-Anaheim, CA;Be...      Bellflower    CA
# 72     87121;NM;Albuquerque, NM;Albuquerque;Bernalill...     Albuquerque    NM
# 73     76244;TX;Dallas-Fort Worth-Arlington, TX;Fort ...      Fort Worth    TX
# 74     77083;TX;Houston-The Woodlands-Sugar Land, TX;...         Houston    TX
# 75     10002;NY;New York-Newark-Jersey City, NY-NJ-PA...        New York    NY
# ...                                                  ...             ...   ...
# 89299  78402;TX;Corpus Christi, TX;Corpus Christi;Nue...  Corpus Christi    TX
# 89300    3293;NH;Lebanon, NH-VT;Woodstock;Grafton County       Woodstock    NH
# 89301        83025;WY;Jackson, WY-ID;Wilson;Teton County          Wilson    WY
# 89302  1718;MA;Boston-Cambridge-Newton, MA-NH;Acton;M...           Acton    MA
# 89303                       40363;KY;nan;nan;Owen County             nan    KY
#
# [29394 rows x 5 columns]

# %%
check_merge_metro.loc[:, "city"] = check_merge_zip["region"].str.split(",").str[0]
check_merge_metro.loc[:, "state"] = check_merge_zip["region"].str.split(",").str[1]
check_merge_metro
# Out:
#        region_id region_type              region city state
# 1         394415       metro      Bridgeport, CT  NaN   NaN
# 2         394653       metro      Greenville, SC  NaN   NaN
# 3         394312       metro     Albuquerque, NM  NaN   NaN
# 4         394357       metro     Bakersfield, CA  NaN   NaN
# 5         394308       metro          Albany, NY  NaN   NaN
# ...          ...         ...                 ...  ...   ...
# 89082     753924       metro  Urban Honolulu, HI  NaN   NaN
# 89083     395169       metro           Tulsa, OK  NaN   NaN
# 89084     394619       metro          Fresno, CA  NaN   NaN
# 89085     395238       metro       Worcester, MA  NaN   NaN
# 89086     394938       metro           Omaha, NE  NaN   NaN
#
# [912 rows x 5 columns]

# %%
check_merge_neigh.loc[:, "city"] = check_merge_neigh["region"].str.split(";").str[4]
check_merge_neigh.loc[:, "state"] = check_merge_neigh["region"].str.split(";").str[1]
check_merge_neigh
# Out:
#        region_id region_type  \
# 155       274772       neigh
# 164       273698       neigh
# 183       275473       neigh
# 306       196538       neigh
# 958       118208       neigh
# ...          ...         ...
# 88516     807945       neigh
# 88517     806920       neigh
# 88518     250248       neigh
# 88519     416777       neigh
# 88520     809280       neigh
#
#                                                   region                city  \
# 155    Northeast Dallas; TX; Dallas-Fort Worth-Arling...              Dallas
# 164    Far North; TX; Dallas-Fort Worth-Arlington, TX...              Dallas
# 183    Southeast Dallas; TX; Dallas-Fort Worth-Arling...              Dallas
# 306    Murray Hill; NY; New York-Newark-Jersey City; ...            New York
# 958    South Los Angeles;CA;Los Angeles-Long Beach-An...  Los Angeles County
# ...                                                  ...                 ...
# 88516     Dellwood Park;TX;Laredo, TX;Laredo;Webb County         Webb County
# 88517  Lake Mathews;CA;Riverside-San Bernardino-Ontar...    Riverside County
# 88518       Central Park;OK;Tulsa, OK;Tulsa;Tulsa County        Tulsa County
# 88519  Archwood Acres;TN;Nashville-Davidson--Murfrees...     Davidson County
# 88520  Laguna Park;NV;Las Vegas-Henderson-Paradise, N...        Clark County
#
#       state
# 155      TX
# 164      TX
# 183      TX
# 306      NY
# 958      CA
# ...     ...
# 88516    TX
# 88517    CA
# 88518    OK
# 88519    TN
# 88520    NV
#
# [22376 rows x 5 columns]

# %%
check_merge_city.loc[:, "city"] = check_merge_city["region"].str.split(";").str[0]
check_merge_city.loc[:, "state"] = check_merge_city["region"].str.split(";").str[1]
check_merge_city
# Out:
#        region_id region_type  \
# 163        32503        city
# 343        17384        city
# 344        13437        city
# 363        47945        city
# 364        12065        city
# ...          ...         ...
# 88996      34596        city
# 88997     173791        city
# 88998       4292        city
# 89002      22347        city
# 89003      37109        city
#
#                                                   region               city  \
# 163              Lincoln;NE;Lincoln, NE;Lancaster County            Lincoln
# 343    Chandler;AZ;Phoenix-Mesa-Chandler, AZ;Maricopa...           Chandler
# 344    Randolph Township; NJ; New York-Newark-Jersey ...  Randolph Township
# 363           Tallahassee;FL;Tallahassee, FL;Leon County        Tallahassee
# 364    Irving;TX;Dallas-Fort Worth-Arlington, TX;Dall...             Irving
# ...                                                  ...                ...
# 88996           Vincent;IA;Fort Dodge, IA;Webster County            Vincent
# 88997   Mackenzie;MO;St. Louis, MO-IL;Saint Louis County          Mackenzie
# 88998                Dalzell;IL;Ottawa, IL;Bureau County            Dalzell
# 89002                  New Pine Creek;OR;nan;Lake County     New Pine Creek
# 89003                Altona;IN;Auburn, IN;De Kalb County             Altona
#
#       state
# 163      NE
# 343      AZ
# 344      NJ
# 363      FL
# 364      TX
# ...     ...
# 88996    IA
# 88997    MO
# 88998    IL
# 89002    OR
# 89003    IN
#
# [25804 rows x 5 columns]

# %%
check_merge_county.loc[:, "city"] = check_merge_county["region"].str.split(";").str[0]
check_merge_county.loc[:, "state"] = check_merge_county["region"].str.split(";").str[1]
check_merge_county
# Out:
#        region_id region_type  \
# 880         2841      county
# 915         1286      county
# 916          445      county
# 918         2049      county
# 932          386      county
# ...          ...         ...
# 82375       2400      county
# 82494       2353      county
# 82799       1077      county
# 82951        263      county
# 83099        131      county
#
#                                                   region              city  \
# 880    San Diego County;CA;San Diego-Chula Vista-Carl...  San Diego County
# 915    Orange County;CA;Los Angeles-Long Beach-Anahei...     Orange County
# 916     Clark County;NV;Las Vegas-Henderson-Paradise, NV      Clark County
# 918    Tarrant County;TX;Dallas-Fort Worth-Arlington, TX    Tarrant County
# 932        Bexar County;TX;San Antonio-New Braunfels, TX      Bexar County
# ...                                                  ...               ...
# 82375                             Manistee County;MI;nan   Manistee County
# 82494                  Humboldt County;NV;Winnemucca, NV   Humboldt County
# 82799                               Hardin County;IA;nan     Hardin County
# 82951                                 Otoe County;NE;nan       Otoe County
# 83099                                 Clay County;TN;nan       Clay County
#
#       state
# 880      CA
# 915      CA
# 916      NV
# 918      TX
# 932      TX
# ...     ...
# 82375    MI
# 82494    NV
# 82799    IA
# 82951    NE
# 83099    TN
#
# [2711 rows x 5 columns]

# %%
check_merge_combine = pd.concat([check_merge_zip, check_merge_metro, check_merge_neigh, check_merge_city, check_merge_county], ignore_index=True)
check_merge_combine
# Out:
#        region_id region_type  \
# 0          96208         zip
# 1          95315         zip
# 2          91325         zip
# 3          91732         zip
# 4          61616         zip
# ...          ...         ...
# 81192       2400      county
# 81193       2353      county
# 81194       1077      county
# 81195        263      county
# 81196        131      county
#
#                                                   region             city  \
# 0      90706;CA;Los Angeles-Long Beach-Anaheim, CA;Be...       Bellflower
# 1      87121;NM;Albuquerque, NM;Albuquerque;Bernalill...      Albuquerque
# 2      76244;TX;Dallas-Fort Worth-Arlington, TX;Fort ...       Fort Worth
# 3      77083;TX;Houston-The Woodlands-Sugar Land, TX;...          Houston
# 4      10002;NY;New York-Newark-Jersey City, NY-NJ-PA...         New York
# ...                                                  ...              ...
# 81192                             Manistee County;MI;nan  Manistee County
# 81193                  Humboldt County;NV;Winnemucca, NV  Humboldt County
# 81194                               Hardin County;IA;nan    Hardin County
# 81195                                 Otoe County;NE;nan      Otoe County
# 81196                                 Clay County;TN;nan      Clay County
#
#       state
# 0        CA
# 1        NM
# 2        TX
# 3        TX
# 4        NY
# ...     ...
# 81192    MI
# 81193    NV
# 81194    IA
# 81195    NE
# 81196    TN
#
# [81197 rows x 5 columns]

# %%
merged_df_clean = pd.merge(data_2014, check_merge_combine.drop(["region_type","region"], axis=1), on="region_id", how="inner")
merged_df_clean["date"] = pd.to_datetime(merged_df_clean["date"])
merged_df_clean
# Out:
#         indicator_id  region_id       date          value           city state
# 0               ZATT       1146 2014-03-31  288076.000000  Lehigh County    PA
# 1               ZATT       1146 2014-04-30  289159.000000  Lehigh County    PA
# 2               ZATT       1146 2014-01-31  296171.523003  Lehigh County    PA
# 3               ZATT       1146 2014-02-28  299399.064690  Lehigh County    PA
# 4               ZATT       1146 2014-05-31  313516.092252  Lehigh County    PA
# ...              ...        ...        ...            ...            ...   ...
# 6496380         Z4BR      95019 2014-09-30  189555.079592   Sierra Vista    AZ
# 6496381         Z4BR      95019 2014-10-31  188631.870053   Sierra Vista    AZ
# 6496382         Z4BR      95019 2014-11-30  188488.806946   Sierra Vista    AZ
# 6496383         Z4BR      95019 2014-12-31  188611.779814   Sierra Vista    AZ
# 6496384         Z4BR      95019 2014-01-31  194980.837292   Sierra Vista    AZ
#
# [6496385 rows x 6 columns]

# %%
states = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY"
}

# %%
crime_df
# Out:
#         Record ID Agency Code      Agency Name       Agency Type        City  \
# 0               1     AK00101        Anchorage  Municipal Police   Anchorage
# 1               2     AK00101        Anchorage  Municipal Police   Anchorage
# 2               3     AK00101        Anchorage  Municipal Police   Anchorage
# 3               4     AK00101        Anchorage  Municipal Police   Anchorage
# 4               5     AK00101        Anchorage  Municipal Police   Anchorage
# ...           ...         ...              ...               ...         ...
# 638449     638450     WY01500      Park County           Sheriff        Park
# 638450     638451     WY01700  Sheridan County           Sheriff    Sheridan
# 638451     638452     WY01701         Sheridan  Municipal Police    Sheridan
# 638452     638453     WY01800  Sublette County           Sheriff    Sublette
# 638453     638454     WY01902     Rock Springs  Municipal Police  Sweetwater
#
#           State  Year      Month  Incident              Crime Type  ...  \
# 0        Alaska  1980    January         1  Murder or Manslaughter  ...
# 1        Alaska  1980      March         1  Murder or Manslaughter  ...
# 2        Alaska  1980      March         2  Murder or Manslaughter  ...
# 3        Alaska  1980      April         1  Murder or Manslaughter  ...
# 4        Alaska  1980      April         2  Murder or Manslaughter  ...
# ...         ...   ...        ...       ...                     ...  ...
# 638449  Wyoming  2014    January         1  Murder or Manslaughter  ...
# 638450  Wyoming  2014       June         1  Murder or Manslaughter  ...
# 638451  Wyoming  2014  September         1  Murder or Manslaughter  ...
# 638452  Wyoming  2014   December         1  Murder or Manslaughter  ...
# 638453  Wyoming  2014  September         1  Murder or Manslaughter  ...
#
#        Victim Ethnicity Perpetrator Sex  Perpetrator Age  \
# 0               Unknown            Male               15
# 1               Unknown            Male               42
# 2               Unknown         Unknown                0
# 3               Unknown            Male               42
# 4               Unknown         Unknown                0
# ...                 ...             ...              ...
# 638449         Hispanic         Unknown                0
# 638450          Unknown            Male               57
# 638451          Unknown          Female               22
# 638452     Not Hispanic            Male               31
# 638453     Not Hispanic          Female               24
#
#                      Perpetrator Race Perpetrator Ethnicity  Relationship  \
# 0       Native American/Alaska Native               Unknown  Acquaintance
# 1                               White               Unknown  Acquaintance
# 2                             Unknown               Unknown       Unknown
# 3                               White               Unknown  Acquaintance
# 4                             Unknown               Unknown       Unknown
# ...                               ...                   ...           ...
# 638449                        Unknown               Unknown       Unknown
# 638450                          White               Unknown  Acquaintance
# 638451         Asian/Pacific Islander               Unknown      Daughter
# 638452                          White          Not Hispanic      Stranger
# 638453                          White          Not Hispanic      Daughter
#
#                Weapon Victim Count Perpetrator Count Record Source
# 0        Blunt Object            0                 0           FBI
# 1       Strangulation            0                 0           FBI
# 2             Unknown            0                 0           FBI
# 3       Strangulation            0                 0           FBI
# 4             Unknown            0                 1           FBI
# ...               ...          ...               ...           ...
# 638449        Handgun            0                 0           FBI
# 638450        Handgun            0                 0           FBI
# 638451    Suffocation            0                 0           FBI
# 638452          Knife            0                 1           FBI
# 638453   Blunt Object            0                 1           FBI
#
# [638454 rows x 24 columns]

# %%
merged_df_clean["city_state"] = merged_df_clean["city"] + ", " + merged_df_clean["state"]
final_zilow_df = pd.merge(merged_df_clean, indicator_df, on="indicator_id", how="inner")
crime_df["state_abbrev"] = crime_df["State"].map(states)
crime_df["city_state"] = crime_df["City"] + ", " + crime_df["state_abbrev"]
crime_df_max = crime_df.groupby(["city_state", "Year", "Month"])["Incident"].max().reset_index()
crime_df_sum = crime_df_max.groupby("city_state")["Incident"].sum()
#final_df = pd.merge(final_zilow_df, crime_df, on="city_state", how="left")
final_df = pd.merge(final_zilow_df, crime_df_sum.rename("total_incidents"), on="city_state", how="inner")
final_df.to_csv("data/final_df.csv", index=False)
